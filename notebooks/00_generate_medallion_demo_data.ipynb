# %% [markdown]
# # 00 Generate Medallion Demo Data
#
# Generate synthetic Bronze, Silver, and Gold demo data locally. Generated files are written to `data/generated/` and should not be committed.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from customer_pricing_analytics.medallion.pipeline import run_medallion_demo_pipeline

result = run_medallion_demo_pipeline(
    output_dir=PROJECT_ROOT / 'data' / 'generated',
    n_customers=100,
    n_opportunities=300,
    active_share=0.25,
    random_state=42,
)
result

# %% [markdown]
# All generated records are synthetic. No competitor data is generated or used.
