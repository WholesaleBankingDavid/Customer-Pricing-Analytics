# %% [markdown]
# # 00 Visualize Medallion Data Model
#
# Generate Mermaid diagrams from the schema registry. This notebook does not require `data/generated/` and does not load real or synthetic records.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from customer_pricing_analytics.visualization.schema_registry import get_schema_registry
from customer_pricing_analytics.visualization.mermaid_generator import (
    generate_medallion_layer_flow,
    generate_bronze_source_systems,
    generate_silver_erd,
    generate_gold_model_marts,
    generate_deal_facility_pricing_lineage,
    generate_field_lineage_examples,
)

registry = get_schema_registry()
len(registry), sorted({schema.layer for schema in registry.values()})

# %% [markdown]
# Bronze = raw source system exports. Silver = cleaned business entities. Gold = analytical marts. Models and dashboards sit on Gold, not Bronze.
#
# Deal is the commercial decision and negotiation object. Facility/Product is the pricing and economics calculation object. Outcomes live on Deal level; pricing lives on Facility/Quote level.

# %%
print(generate_medallion_layer_flow(registry))

# %%
print(generate_bronze_source_systems(registry))

# %%
print(generate_silver_erd(registry))

# %%
print(generate_gold_model_marts(registry))

# %%
print(generate_deal_facility_pricing_lineage(registry))

# %%
print(generate_field_lineage_examples())
