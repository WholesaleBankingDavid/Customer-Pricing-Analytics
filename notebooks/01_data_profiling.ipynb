# %% [markdown]
# # 01 Data Profiling
#
# Profile the existing workbook without assuming a fixed schema. Avoid displaying full sensitive datasets.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from customer_pricing_analytics.config import DEFAULT_WORKBOOK_PATH
from customer_pricing_analytics.data_loading import list_sheets, load_sheet
from customer_pricing_analytics.data_profiling import profile_workbook

workbook_path = DEFAULT_WORKBOOK_PATH
workbook_path

# %%
sheets = list_sheets(workbook_path)
sheets

# %%
profiles = profile_workbook(workbook_path)
profiles

# %%
# Inspect a small sample only. Do not expose full source data in shared outputs.
first_sheet = sheets[0]
load_sheet(workbook_path, first_sheet).head(3)
